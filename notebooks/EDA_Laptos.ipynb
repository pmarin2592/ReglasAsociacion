# %% [markdown]
# # EDA Laptos

# %% [markdown]
# ## Librerias

# %%
import warnings
import pandas as pd
import numpy  as np
import seaborn as sns
import matplotlib.pyplot as plt
# Suppress all warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Clases

# %%
from src.utils import path

# %% [markdown]
# ## Carga de DataSet

# %%
directorio_proyecto = path.obtener_ruta_local()
df = pd.read_csv(directorio_proyecto+'\\data\\raw\\dataset_laptos.csv',delimiter = ',',decimal = ".", encoding='utf-8')

# %%
# primeras filas
print("PRIMERAS FILAS DEL DATASET")
display(df.head(5))

print("ÚLTIMAS FILAS DEL DATASET")
display(df.tail(5))
# Out:
# PRIMERAS FILAS DEL DATASET
#    Unnamed: 0                                               link  \
# 0           0  https://www.flipkart.com/asus-rog-strix-scar-1...
# 1           1  https://www.flipkart.com/asus-rog-strix-scar-1...
# 2           2  https://www.flipkart.com/hp-victus-ryzen-7-oct...
# 3           3  https://www.flipkart.com/lenovo-ideapad-gaming...
# 4           4  https://www.flipkart.com/lenovo-yoga-slim-7-co...
#
#                                                 name  user rating      Price  \
# 0  ASUS ROG Strix SCAR 17 Core i9 12th Gen - (32 ...          5.0  ?2,34,990
# 1  ASUS ROG Strix SCAR 15 Core i9 12th Gen - (32 ...          NaN  ?2,29,990
# 2  HP Victus Ryzen 7 Octa Core 5800H - (16 GB/512...          NaN  ?1,04,091
# 3  Lenovo IdeaPad Gaming 3i Ryzen 7 Octa Core R7-...          NaN    ?87,717
# 4  Lenovo Yoga Slim 7 Core i5 11th Gen - (16 GB/5...          NaN    ?75,990
#
#                                        Sales Package    Model Number  \
# ...

# %%
df = df[['name', 'Sales Package', 'Color','Type','Suitable For','Processor Brand','Processor Name','SSD Capacity','RAM','RAM Type','Graphic Processor','Operating System']]

# %%
# Dimensiones del dataset
print("DIMENSIONES DEL DATASET")
print(f"Número de filas: {df.shape[0]}")
print(f"Número de columnas: {df.shape[1]}")

# Información general
print("INFORMACIÓN GENERAL")
df.info()
# Out:
# DIMENSIONES DEL DATASET
# Número de filas: 984
# Número de columnas: 12
# INFORMACIÓN GENERAL
# <class 'pandas.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               984 non-null    str
#  1   Sales Package      984 non-null    str
#  2   Color              984 non-null    str
#  3   Type               984 non-null    str
#  4   Suitable For       984 non-null    str
#  5   Processor Brand    984 non-null    str
#  6   Processor Name     984 non-null    str
#  7   SSD Capacity       876 non-null    str
#  8   RAM                984 non-null    str
#  9   RAM Type           984 non-null    str
#  10  Graphic Processor  964 non-null    str
#  11  Operating System   984 non-null    str
# dtypes: str(12)
# memory usage: 92.4 KB

# %%
# Tipos de datos
print("TIPOS DE DATOS")
print(df.dtypes)
# Out:
# TIPOS DE DATOS
# name                 str
# Sales Package        str
# Color                str
# Type                 str
# Suitable For         str
# Processor Brand      str
# Processor Name       str
# SSD Capacity         str
# RAM                  str
# RAM Type             str
# Graphic Processor    str
# Operating System     str
# dtype: object

# %%
# Estadísticas descriptivas de variables numéricas
print("ESTADÍSTICAS DESCRIPTIVAS - VARIABLES NUMÉRICAS")
display(df.describe().T)

# Estadísticas adicionales
print("ESTADÍSTICAS ADICIONALES")
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
for col in numeric_cols:
    print(f"\n{col}:")
    print(f"  Media: {df[col].mean():.2f}")
    print(f"  Mediana: {df[col].median():.2f}")
    print(f"  Moda: {df[col].mode().values[0] if len(df[col].mode()) > 0 else 'N/A'}")
    print(f"  Desviación estándar: {df[col].std():.2f}")
    print(f"  Varianza: {df[col].var():.2f}")
    print(f"  Asimetría (Skewness): {df[col].skew():.2f}")
    print(f"  Curtosis (Kurtosis): {df[col].kurtosis():.2f}")
# Out:
# ESTADÍSTICAS DESCRIPTIVAS - VARIABLES NUMÉRICAS
#                   count unique  \
# name                984    943
# Sales Package       984    106
# Color               984    132
# Type                984      9
# Suitable For        984     52
# Processor Brand     984      5
# Processor Name      984     30
# SSD Capacity        876      5
# RAM                 984      4
# RAM Type            984      8
# Graphic Processor   964    151
# Operating System    984     10
#
#                                                                  top freq
# name               ASUS ROG Strix SCAR 17 Core i9 12th Gen - (32 ...    2
# Sales Package      Laptop, Power Adaptor, User Guide, Warranty Do...  411
# Color                                                          Black  101
# Type                                           Thin and Light Laptop  503
# Suitable For                               Processing & Multitasking  535
# ...

# %%
# Estadísticas de variables categóricas
print("ESTADÍSTICAS DESCRIPTIVAS - VARIABLES CATEGÓRICAS")

categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"\n{col}:")
    print(f"  Valores únicos: {df[col].nunique()}")
    print(f"  Valor más frecuente: {df[col].mode().values[0] if len(df[col].mode()) > 0 else 'N/A'}")
    print(f"  Top 5 valores:")
    print(df[col].value_counts().head())
# Out:
# ESTADÍSTICAS DESCRIPTIVAS - VARIABLES CATEGÓRICAS
#
# name:
#   Valores únicos: 943
#   Valor más frecuente: ASUS Core i5 11th Gen - (16 GB/512 GB SSD/Windows 11 Home) UX363EA-HP562WS Thin and Light Laptop  (13.3 Inch, Pine Grey, 1.30 Kg, With MS Office)
#   Top 5 valores:
# name
# ASUS ROG Strix SCAR 17 Core i9 12th Gen - (32 GB/1 TB SSD/Windows 11 Home/8 GB Graphics/NVIDIA GeForce RTX 3070 Ti) G733ZW-LL139WS Gaming Laptop  (17.3 inch, Off Black, 2.90 kg, With MS Office)                  2
# ASUS ROG Strix SCAR 15 Core i9 12th Gen - (32 GB/1 TB SSD/Windows 11 Home/8 GB Graphics/NVIDIA GeForce RTX 3070 Ti) G533ZW-LN136WS Gaming Laptop  (15.6 inch, Off Black, 2.30 kg, With MS Office)                  2
# HP Victus Ryzen 7 Octa Core 5800H - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce RTX 3050) 16-e0351AX Gaming Laptop  (16.1 inch, Mica Silver, 2.48 kg, With MS Office)                           2
# ...

# %%
# Análisis de duplicados
print("ANÁLISIS DE VALORES DUPLICADOS")
print(f"Número de filas duplicadas: {df.duplicated().sum()}")
print(f"Porcentaje de duplicados: {(df.duplicated().sum() / len(df)) * 100:.2f}%")

if df.duplicated().sum() > 0:
    print("\nFilas duplicadas:")
    display(df[df.duplicated(keep=False)].sort_values(by=df.columns.tolist()))
# Out:
# ANÁLISIS DE VALORES DUPLICADOS
# Número de filas duplicadas: 40
# Porcentaje de duplicados: 4.07%
#
# Filas duplicadas:
#                                                   name  \
# 237  ASUS Core i5 11th Gen - (16 GB/512 GB SSD/Wind...
# 247  ASUS Core i5 11th Gen - (16 GB/512 GB SSD/Wind...
# 15   ASUS ROG Flow X13 (2021) Ryzen 9 Octa Core Ryz...
# 87   ASUS ROG Flow X13 (2021) Ryzen 9 Octa Core Ryz...
# 666  ASUS ROG Strix G15 (2021) Ryzen 7 Octa Core 48...
# ..                                                 ...
# 92   realme Book Prime Core i5 11th Gen - (16 GB/51...
# 19   realme Book Prime Core i5 11th Gen - (16 GB/51...
# 91   realme Book Prime Core i5 11th Gen - (16 GB/51...
# 18   realme Book Prime Core i5 11th Gen - (16 GB/51...
# 90   realme Book Prime Core i5 11th Gen - (16 GB/51...
#
#                                          Sales Package         Color  \
# 237  Laptop, Power Adaptor, User Guide, Warranty Do...     Pine Grey
# ...

# %%
# Análisis de nulos
print("ANÁLISIS DE VALORES NULOS")
print(f"Total de valores nulos: {df.isnull().sum().sum()}")
print(f"Porcentaje de nulos sobre el total: {(df.isnull().sum().sum() / df.size) * 100:.2f}%")

print("\nNulos por columna:")
nulos_por_col = df.isnull().sum()
porcentaje_por_col = (df.isnull().sum() / len(df)) * 100
resumen_nulos = pd.DataFrame({
    'Nulos': nulos_por_col,
    'Porcentaje': porcentaje_por_col.map('{:.2f}%'.format)
})
display(resumen_nulos[resumen_nulos['Nulos'] > 0])

if df.isnull().sum().sum() > 0:
    print("\nFilas con al menos un nulo:")
    display(df[df.isnull().any(axis=1)])
# Out:
# ANÁLISIS DE VALORES NULOS
# Total de valores nulos: 128
# Porcentaje de nulos sobre el total: 1.08%
#
# Nulos por columna:
#                    Nulos Porcentaje
# SSD Capacity         108     10.98%
# Graphic Processor     20      2.03%
# Filas con al menos un nulo:
#                                                   name  \
# 50   ASUS VivoBook 15 Core i3 10th Gen - (8 GB/1 TB...
# 101  ASUS VivoBook 15 (2021) Core i5 10th Gen - (8 ...
# 111  ASUS VivoBook 15 (2021) Core i3 11th Gen - (8 ...
# 115  HP Chromebook Celeron Quad Core - (4 GB/64 GB ...
# 116  HP Chromebook Celeron Dual Core - (4 GB/64 GB ...
# ..                                                 ...
# 968  Lenovo Ideapad S145 Core i3 7th Gen - (4 GB/1 ...
# 971  HP 250 Core i5 10th Gen - (8 GB/1 TB HDD/Windo...
# 972  Lenovo Core i5 8th Gen - (4 GB/1 TB HDD/DOS) V...
# 982  HP 14a Celeron Dual Core - (4 GB/64 GB EMMC St...
# 983  Lenovo Core i3 10th Gen - (4 GB/1 TB HDD/Windo...
#
# ...

# %%
df = df[['name', 'Sales Package', 'Color','Type','Suitable For','Processor Brand','Processor Name','RAM','RAM Type','Operating System']]

# %%
# Boxplots para detectar outliers
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

if len(numeric_cols) > 0:
    n_cols = 3
    n_rows = (len(numeric_cols) + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5*n_rows))
    axes = axes.flatten() if len(numeric_cols) > 1 else [axes]

    for idx, col in enumerate(numeric_cols):
        axes[idx].boxplot(df[col].dropna(), vert=True)
        axes[idx].set_title(f'Boxplot de {col}', fontweight='bold')
        axes[idx].set_ylabel(col)
        axes[idx].grid(alpha=0.3)

    # Ocultar ejes vacíos
    for idx in range(len(numeric_cols), len(axes)):
        axes[idx].set_visible(False)

    plt.tight_layout()
    plt.show()
